# %%
import pandas as pd
import numpy as np

# %%
## shift + enter

# %%
## load my data

df = pd.read_csv("bigmart_train.csv")

# %%
df = pd.read_csv("bigmart_train.csv")

# %%
df = pd.read_csv("bigmart_train.csv")

# %%
## dataframe

# %%
## listing out the first five rows of data
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
## last five observations

df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
df.tail(15)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8510           FDN58       13.800          Regular         0.056862
# 8511           FDF05       17.500          Low Fat         0.026980
# 8512           FDR26       20.700          Low Fat         0.042801
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# ...

# %%
#df

# %%
## shape of my data - number of records and variables

df.shape
# Out:
# (8523, 12)

# %%
## check data types
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
## how many unique values are there in a clumn

df["Outlet_Establishment_Year"].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004])

# %%
df["Outlet_Establishment_Year"].nunique()
# Out:
# 9

# %%
### check for the missing values

df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
## handle missing values

## drop the column
## fill the missing values
## mean median mode

# %%
## whenevr there is a missing value in a numerical valirable, i can use mean or median
## categorical column - mode

## numerical variable should follow normal distribution

# %%
## fil the missing values

df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
import seaborn as sns

sns.distplot(df["Item_MRP"])
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
## fill missing values

df["Item_Weight"] = df["Item_Weight"].fillna(12.6)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
## rop this column

df = df.drop("Outlet_Size", axis=1)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
## filter the daaframe

df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2009               Tier 3  Supermarket Type2
# ...

# %%
test = df.iloc[30:40, 2:10]

# %%
test
# Out:
#    Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 30          Low Fat         0.170349                  Dairy   55.7956
# 31          Low Fat         0.080829     Health and Hygiene   96.4436
# 32          Low Fat         0.000000            Snack Foods  256.6672
# 33          Low Fat         0.000000                 Breads   93.1436
# 34          Low Fat         0.097904            Soft Drinks  174.8738
# 35          Low Fat         0.089291     Health and Hygiene  146.7102
# 36          Regular         0.059512  Fruits and Vegetables  128.0678
# 37          Regular         0.113124            Soft Drinks  122.5388
# 38          Regular         0.123111            Snack Foods   36.9874
# 39          Low Fat         0.026481            Snack Foods   87.6198
#
#    Outlet_Identifier  Outlet_Establishment_Year Outlet_Location_Type  \
# 30            OUT010                       1998               Tier 3
# ...

# %%
df.loc[30:35, 2:7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-65f681352f3e> in <module>
# ----> 1 df.loc[30:35, 2:7]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     748                 continue
# ...

# %%
df.loc[30:35, ["Item_Visibility", "Item_Type"] ]
# Out:
#     Item_Visibility           Item_Type
# 30         0.170349               Dairy
# 31         0.080829  Health and Hygiene
# 32         0.000000         Snack Foods
# 33         0.000000              Breads
# 34         0.097904         Soft Drinks
# 35         0.089291  Health and Hygiene

# %%
## correlation

# %%
df.corr()*100

# %% [markdown]
# ## outliers

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2009               Tier 3  Supermarket Type2
# ...

# %%
sns.distplot(df["Item_Outlet_Sales"])
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
## box plot

import seaborn as sns

sns.boxplot(df["Item_Outlet_Sales"])
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
### Chnage the data types for varibale

df["Item_Outlet_Sales"] = df["Item_Outlet_Sales"].astype("int")

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales              int64
# dtype: object

# %%
### groupby

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2009               Tier 3  Supermarket Type2
# ...

# %%
df.groupby("Outlet_Type")["Item_Outlet_Sales"].mean()
# Out:
# Outlet_Type
# Grocery Store         339.321330
# Supermarket Type1    2315.680653
# Supermarket Type2    1994.993534
# Supermarket Type3    3693.533690
# Name: Item_Outlet_Sales, dtype: float64

# %%
df.groupby(["Outlet_Type", "Item_Type"])["Item_Outlet_Sales"].mean()
# Out:
# Outlet_Type        Item_Type
# Grocery Store      Baking Goods      291.564706
#                    Breads            381.424242
#                    Breakfast         412.368421
#                    Canned            352.328767
#                    Dairy             341.369565
#                                        ...
# Supermarket Type3  Others           2700.466667
#                    Seafood          2686.428571
#                    Snack Foods      3744.620438
#                    Soft Drinks      3284.377778
#                    Starchy Foods    3511.714286
# Name: Item_Outlet_Sales, Length: 64, dtype: float64

# %%
## filter the dataframe

df_99 = df[df["Outlet_Establishment_Year"] ==1999]

# %%
#df[df["Outlet_Establishment_Year"] ==1999]

# %%
df.groupby(["Outlet_Type", "Item_Type"])[["Item_Outlet_Sales","Item_MRP" ]].mean()
# Out:
#                                  Item_Outlet_Sales    Item_MRP
# Outlet_Type       Item_Type
# Grocery Store     Baking Goods          291.564706  126.438068
#                   Breads                381.424242  146.452873
#                   Breakfast             412.368421  147.026989
#                   Canned                352.328767  138.080808
#                   Dairy                 341.369565  147.166715
# ...                                            ...         ...
# Supermarket Type3 Others               2700.466667  106.779053
#                   Seafood              2686.428571  124.028286
#                   Snack Foods          3744.620438  144.574508
#                   Soft Drinks          3284.377778  123.313587
#                   Starchy Foods        3511.714286  143.078386
#
# [64 rows x 2 columns]

# %%
var = df.groupby(["Outlet_Type", "Item_Type"])[["Item_Outlet_Sales","Item_MRP" ]].mean()

# %%
var.get_group("Grocery Store")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-a873c321a263> in <module>
# ----> 1 var.get_group("Grocery Store")
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
df["Outlet_Type"].mode()
# Out:
# 0    Supermarket Type1
# dtype: object

# %%
## concatenation

df1 = pd.DataFrame({"city": ["a","b","c"], "age": [34,56,78], "volume": [112,345,678]})

# %%
df1
# Out:
#   city  age  volume
# 0    a   34     112
# 1    b   56     345
# 2    c   78     678

# %%
df2 = pd.DataFrame({"city": ["d","e"], "age": [100,90], "salary": [2000,3000], "state":["TN", "KA"]})

# %%
df2
# Out:
#   city  age  salary state
# 0    d  100    2000    TN
# 1    e   90    3000    KA

# %%
pd.concat([df1,df2])
# Out:
#   city  age  volume  salary state
# 0    a   34   112.0     NaN   NaN
# 1    b   56   345.0     NaN   NaN
# 2    c   78   678.0     NaN   NaN
# 0    d  100     NaN  2000.0    TN
# 1    e   90     NaN  3000.0    KA

# %%
pd.concat([df1,df2], axis=1)
# Out:
#   city  age  volume city    age  salary state
# 0    a   34     112    d  100.0  2000.0    TN
# 1    b   56     345    e   90.0  3000.0    KA
# 2    c   78     678  NaN    NaN     NaN   NaN

# %%
pd.concat([df1,df2], ignore_index=True)
# Out:
#   city  age  volume  salary state
# 0    a   34   112.0     NaN   NaN
# 1    b   56   345.0     NaN   NaN
# 2    c   78   678.0     NaN   NaN
# 3    d  100     NaN  2000.0    TN
# 4    e   90     NaN  3000.0    KA

# %%
### MErging

# %%
df1
# Out:
#   city  age  volume
# 0    a   34     112
# 1    b   56     345
# 2    c   78     678

# %%
df2
# Out:
#   city  age  salary state
# 0    d  100    2000    TN
# 1    e   90    3000    KA

# %%
df2 = pd.DataFrame({"city": ["a","e"], "salary": [2000,3000], "state":["TN", "KA"]})

# %%
df2
# Out:
#   city  salary state
# 0    a    2000    TN
# 1    e    3000    KA

# %%
df1
# Out:
#   city  age  volume
# 0    a   34     112
# 1    b   56     345
# 2    c   78     678

# %%
pd.merge(df1,df2, on="city", how="inner")
# Out:
#   city  age  volume  salary state
# 0    a   34     112    2000    TN

# %%
pd.merge(df1,df2, on="city", how="outer")
# Out:
#   city   age  volume  salary state
# 0    a  34.0   112.0  2000.0    TN
# 1    b  56.0   345.0     NaN   NaN
# 2    c  78.0   678.0     NaN   NaN
# 3    e   NaN     NaN  3000.0    KA

# %%
df1
# Out:
#   city  age  volume
# 0    a   34     112
# 1    b   56     345
# 2    c   78     678

# %%
df2
# Out:
#   city  salary state
# 0    a    2000    TN
# 1    e    3000    KA

# %%
pd.merge(df1,df2, on="city", how="left")
# Out:
#   city  age  volume  salary state
# 0    a   34     112  2000.0    TN
# 1    b   56     345     NaN   NaN
# 2    c   78     678     NaN   NaN

# %%
pd.merge(df2,df1, on="city", how="left")
# Out:
#   city  salary state   age  volume
# 0    a    2000    TN  34.0   112.0
# 1    e    3000    KA   NaN     NaN

# %%
pd.merge(df1,df2, on="city", how="right")
# Out:
#   city   age  volume  salary state
# 0    a  34.0   112.0    2000    TN
# 1    e   NaN     NaN    3000    KA

# %%
#pd.merge(df2,df1, on=["city", "col2"], how="left")
